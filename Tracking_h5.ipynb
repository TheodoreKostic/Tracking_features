# %%
import numpy as np
import matplotlib.pyplot as plt
import pyflct
from scipy.stats import pearsonr
import h5py

# %% [markdown]
# <h1 style = "color:black; font-family:Times New Roman">Provera jednog fajla</h1>

# %%
f1 = h5py.File("SVGd3r13bvCcp1p_rhd270_46170s_shrunk.h5", "r")

# %%
f1.keys()
# Out:
# <KeysViewHDF5 ['T', 'bolometric', 'bx', 'by', 'bz', 'vx', 'vy', 'vz']>

# %%
T1 = f1['T']
T1 = np.asarray(T1)
T1 = T1.transpose(1, 2, 0)

# %%
T1.shape
# Out:
# (480, 480, 40)

# %%
plt.figure(figsize=[13,5])
plt.imshow(T1[:,:,30], cmap = 'magma')
plt.colorbar()

# %%
print(np.asarray(f1['vx']))
# Out:
# [[[ 9.14185781e+04  1.46013797e+05  1.93263438e+05 ...  8.42770020e+03
#     1.67024609e+04  4.22886641e+04]
#   [ 9.56640625e+04  1.53099547e+05  1.94197516e+05 ... -3.62657532e+02
#     1.60000947e+04  4.66372578e+04]
#   [ 8.82724453e+04  1.55481703e+05  1.91436844e+05 ... -5.77380615e+02
#     9.66710938e+03  3.60686797e+04]
#   ...
#   [-3.41875234e+04 -9.80444219e+04 -1.01818195e+05 ...  1.72792875e+05
#     9.57395547e+04  3.65740117e+04]
#   [-2.65737695e+04 -8.78642090e+03  6.26569961e+04 ...  7.57007734e+04
#     1.84963262e+04 -1.06905566e+04]
#   [ 4.87843125e+04  1.02909328e+05  1.66153516e+05 ...  2.09027715e+04
#     7.12926904e+03  1.68108730e+04]]
#
#  [[ 9.94874219e+04  1.82679672e+05  2.45671406e+05 ... -1.89100332e+04
#    -2.50280723e+04  1.51288955e+04]
#   [ 9.89587578e+04  2.03293172e+05  2.66060031e+05 ... -1.49460801e+04
#    -1.58961123e+04  1.46500146e+04]
#   [ 8.97342266e+04  2.11679984e+05  2.63875094e+05 ... -1.11285156e+04
# ...

# %%
print(np.asarray(f1['bz']))
# Out:
# [[[-1.40132561e-01  4.76034820e-01  1.07579732e+00 ... -5.77396774e+00
#    -3.98014355e+00 -1.05228174e+00]
#   [-1.05778563e+00 -4.33087111e-01 -2.11667871e+00 ... -4.31974697e+00
#    -3.73203850e+00 -2.39047909e+00]
#   [-9.61935520e-01 -1.69596374e+00 -1.09040947e+01 ... -3.14179015e+00
#    -3.00156784e+00 -2.08321214e+00]
#   ...
#   [ 1.78996094e+02  1.63683884e+02  1.34342331e+02 ... -2.24277172e+01
#     1.20617493e+02  1.84042038e+02]
#   [ 8.67381516e+01  1.15641678e+02  1.02284271e+02 ... -1.03550576e-01
#     5.58940849e+01  5.82885551e+01]
#   [ 1.02233353e+01  2.42715721e+01  2.58247967e+01 ... -3.32299376e+00
#     1.17441738e+00  1.27492917e+00]]
#
#  [[ 5.43698454e+00  4.50077248e+00  4.96387911e+00 ... -4.96570110e+00
#    -1.32932889e+00  3.45361710e+00]
#   [ 2.80579120e-01 -7.74474442e-01 -4.08855629e+00 ... -4.20538616e+00
#    -3.06675220e+00 -7.84607589e-01]
#   [ 5.60677290e-01 -1.25175571e+00 -1.03191252e+01 ... -3.22655439e+00
# ...

# %%
Bz1 = f1['bz']
Bz1 = np.asarray(Bz1)
Bz1 = Bz1.transpose(1, 2, 0)
plt.figure(figsize=[13,5])
plt.imshow(Bz1[:,:,30], cmap = 'PuOr')
plt.colorbar()
