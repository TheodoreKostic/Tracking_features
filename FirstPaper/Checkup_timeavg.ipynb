# %%
import numpy as np
import matplotlib.pyplot as plt
import muram as mio
from astropy.io import fits
import pyflct

# %%
from matplotlib import font_manager
import matplotlib as mpl
font_path = '/home/flow/.fonts/cmunrm.ttf'  # Your font path goes here
#font_path = '/usr/share/fonts/opentype/urw-base35/NimbusRoman-Italic.otf'
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)
mpl.rcParams["font.size"] = 12
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()
plt.rc('axes', unicode_minus=False)

# %%
from scipy.stats import pearsonr

# %%
from scipy.ndimage import gaussian_filter

# %%
def temporal_avg(data_in, start, end):
    tmp_avg = np.mean(data_in[start:end+1], axis = 0)
    return tmp_avg

# %% [markdown]
# <h1>Cadence 10s vs 20, 30, 40, 50 and 60s</h1>

# %%
Vx = fits.open("Velocities_TAU_1_0.fits")[1].data # Vy from Velocities.fits as originally thought
Vy = fits.open("Velocities_TAU_1_0.fits")[0].data # Vx from Velocities.fits as originally thought
Vx = Vx.transpose(0, 2, 1)
Vy = Vy.transpose(0, 2, 1)

# %%
Vx_mean_sim90 = temporal_avg(Vx, 0, 90)
Vx_mean_sim90 = Vx_mean_sim90/1E5

Vy_mean_sim90 = temporal_avg(Vy, 0, 90)
Vy_mean_sim90 = Vy_mean_sim90/1E5

# %%
Rx_10 = pearsonr(Vx_mean_sim90.flatten(), Vx_mean_sim90.flatten())
print(Rx_10)
# Out:
# PearsonRResult(statistic=1.0, pvalue=0.0)

# %%
Ry_10 = pearsonr(Vy_mean_sim90.flatten(), Vy_mean_sim90.flatten())
print(Ry_10)
# Out:
# PearsonRResult(statistic=0.9999999999999993, pvalue=0.0)

# %%
Vx_sec = fits.open("Velocities_TAU_1_0.fits")[1].data # Vy from Velocities.fits as originally thought
Vy_sec = fits.open("Velocities_TAU_1_0.fits")[0].data # Vx from Velocities.fits as originally thought
Vx_sec = Vx_sec[::2]
Vy_sec = Vy_sec[::2]
Vx_sec = Vx_sec.transpose(0, 2, 1)
Vy_sec = Vy_sec.transpose(0, 2, 1)

# %%
Vx_mean2_sim90 = temporal_avg(Vx_sec, 0, 90)
Vx_mean2_sim90 = Vx_mean2_sim90/1E5

Vy_mean2_sim90 = temporal_avg(Vy_sec, 0, 90)
Vy_mean2_sim90 = Vy_mean2_sim90/1E5

# %%
Rx_20 = pearsonr(Vx_mean_sim90.flatten(), Vx_mean2_sim90.flatten())
print(Rx_20)
# Out:
# PearsonRResult(statistic=0.8374244903715158, pvalue=0.0)

# %%
Ry_20 = pearsonr(Vy_mean_sim90.flatten(), Vy_mean2_sim90.flatten())
print(Ry_20)
# Out:
# PearsonRResult(statistic=0.8344736185536425, pvalue=0.0)

# %%
Vx_third = fits.open("Velocities_TAU_1_0.fits")[1].data # Vy from Velocities.fits as originally thought
Vy_third = fits.open("Velocities_TAU_1_0.fits")[0].data # Vx from Velocities.fits as originally thought
Vx_third = Vx_third[::3]
Vy_third = Vy_third[::3]
Vx_third = Vx_third.transpose(0, 2, 1)
Vy_third = Vy_third.transpose(0, 2, 1)

# %%
Vx_mean3_sim90 = temporal_avg(Vx_third, 0, 90)
Vx_mean3_sim90 = Vx_mean3_sim90/1E5

Vy_mean3_sim90 = temporal_avg(Vy_third, 0, 90)
Vy_mean3_sim90 = Vy_mean3_sim90/1E5

# %%
Rx_30 = pearsonr(Vx_mean_sim90.flatten(), Vx_mean3_sim90.flatten())
print(Rx_30)
# Out:
# PearsonRResult(statistic=0.7170846726776603, pvalue=0.0)

# %%
Ry_30 = pearsonr(Vy_mean_sim90.flatten(), Vy_mean3_sim90.flatten())
print(Ry_30)
# Out:
# PearsonRResult(statistic=0.7197599975073351, pvalue=0.0)

# %%
Vx_fourth = fits.open("Velocities_TAU_1_0.fits")[1].data # Vy from Velocities.fits as originally thought
Vy_fourth = fits.open("Velocities_TAU_1_0.fits")[0].data # Vx from Velocities.fits as originally thought
Vx_fourth = Vx_fourth[::4]
Vy_fourth = Vy_fourth[::4]
Vx_fourth = Vx_fourth.transpose(0, 2, 1)
Vy_fourth = Vy_fourth.transpose(0, 2, 1)

# %%
Vx_mean4_sim90 = temporal_avg(Vx_fourth, 0, 90)
Vx_mean4_sim90 = Vx_mean4_sim90/1E5

Vy_mean4_sim90 = temporal_avg(Vy_fourth, 0, 90)
Vy_mean4_sim90 = Vy_mean4_sim90/1E5

# %%
Rx_40 = pearsonr(Vx_mean_sim90.flatten(), Vx_mean4_sim90.flatten())
print(Rx_40)
# Out:
# PearsonRResult(statistic=0.6322682825702569, pvalue=0.0)

# %%
Ry_40 = pearsonr(Vy_mean_sim90.flatten(), Vy_mean4_sim90.flatten())
print(Ry_40)
# Out:
# PearsonRResult(statistic=0.6390034100449724, pvalue=0.0)

# %%
Vx_fifth = fits.open("Velocities_TAU_1_0.fits")[1].data # Vy from Velocities.fits as originally thought
Vy_fifth = fits.open("Velocities_TAU_1_0.fits")[0].data # Vx from Velocities.fits as originally thought
Vx_fifth = Vx_fifth[::5]
Vy_fifth = Vy_fifth[::5]
Vx_fifth = Vx_fifth.transpose(0, 2, 1)
Vy_fifth = Vy_fifth.transpose(0, 2, 1)

# %%
Vx_mean5_sim90 = temporal_avg(Vx_fifth, 0, 90)
Vx_mean5_sim90 = Vx_mean5_sim90/1E5

Vy_mean5_sim90 = temporal_avg(Vy_fifth, 0, 90)
Vy_mean5_sim90 = Vy_mean5_sim90/1E5

# %%
Rx_50 = pearsonr(Vx_mean_sim90.flatten(), Vx_mean5_sim90.flatten())
print(Rx_50)
# Out:
# PearsonRResult(statistic=0.6322377055540321, pvalue=0.0)

# %%
Ry_50 = pearsonr(Vy_mean_sim90.flatten(), Vy_mean5_sim90.flatten())
print(Ry_50)
# Out:
# PearsonRResult(statistic=0.6389330637495962, pvalue=0.0)

# %%
Vx_sixth = fits.open("Velocities_TAU_1_0.fits")[1].data # Vy from Velocities.fits as originally thought
Vy_sixth = fits.open("Velocities_TAU_1_0.fits")[0].data # Vx from Velocities.fits as originally thought
Vx_sixth = Vx_sixth[::6]
Vy_sixth = Vy_sixth[::6]
Vx_sixth = Vx_sixth.transpose(0, 2, 1)
Vy_sixth = Vy_sixth.transpose(0, 2, 1)

# %%
Vx_mean6_sim90 = temporal_avg(Vx_sixth, 0, 90)
Vx_mean6_sim90 = Vx_mean6_sim90/1E5

Vy_mean6_sim90 = temporal_avg(Vy_sixth, 0, 90)
Vy_mean6_sim90 = Vy_mean6_sim90/1E5

# %%
Rx_60 = pearsonr(Vx_mean_sim90.flatten(), Vx_mean6_sim90.flatten())
print(Rx_60)
# Out:
# PearsonRResult(statistic=0.6325723000316557, pvalue=0.0)

# %%
Ry_60 = pearsonr(Vy_mean_sim90.flatten(), Vy_mean6_sim90.flatten())
print(Ry_60)
# Out:
# PearsonRResult(statistic=0.6388043557759945, pvalue=0.0)

# %%
fig = plt.figure(figsize=[12, 20])       
plt.suptitle("Simulated velocities averaged to 15 min; 10 s vs 20, 30, 40, 50, 60 s cadence")# atmos[0] tau


plt.subplot(521)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 10 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(522)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 20 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean2_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(523)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 10 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(524)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 30 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean3_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(525)                                      # atmos[1] temp
#plt.title("Time averaged Simulated Vx, 10 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(526)
plt.title("Time averaged Simulated Vx, 40 s cadence")
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean4_sim90[:,:], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(527)
#plt.title("Time averaged Simulated Vx, 10 s cadence")
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(528)
plt.title("Time averaged Simulated Vx, 50 s cadence")
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean5_sim90[:,:], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(529)                                      # atmos[1] temp
#plt.title("Time averaged Simulated Vx, 10 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(5,2,10)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 60 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean6_sim90[:,:], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

fig.tight_layout()
plt.savefig("Different_cadences.png", dpi = 100)

# %%
fig = plt.figure(figsize=[12, 12])       
plt.suptitle("Simulated velocities averaged to 15 min; 10 s vs 20, 30, 40, 50, 60 s cadence")# atmos[0] tau


plt.subplot(321)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 10 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(322)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 20 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean2_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()


plt.subplot(323)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 30 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean3_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()


plt.subplot(324)
plt.title("Time averaged Simulated Vx, 40 s cadence")
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean4_sim90[:,:], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()


plt.subplot(325)
plt.title("Time averaged Simulated Vx, 50 s cadence")
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean5_sim90[:,:], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()


plt.subplot(326)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 60 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean6_sim90[:,:], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

fig.tight_layout()
plt.savefig("Different_cadences_normal.png", dpi = 100)

# %%
plt.figure(figsize = (8,4))
niz = [Rx_10[0], Rx_20[0], Rx_30[0], Rx_40[0], Rx_50[0], Rx_60[0]]
niz2 = [10, 20, 30, 40, 50, 60]
ni3 = [Ry_10[0], Ry_20[0], Ry_30[0], Ry_40[0], Ry_50[0], Ry_60[0]]
ni2 = [10, 20, 30, 40, 50, 60]
plt.suptitle("Pearson's coefficient for simulated velocities; 10 s vs {20, 30, 40, 50, 60}s")
plt.scatter(niz2, niz, color = "red", label = "Rx", marker = ">", s = 20)
plt.scatter(ni2, ni3, color = "blue", label = "Ry", marker = "<", s = 20)
plt.ylabel("Pearson's coefficient of correlation")
plt.xlabel("Cadence [s]")
#m1, b1, *_ = linregress(Vx_FLCT_1200.flatten(), Vx_FLCT_T.flatten())
#plt.axline(xy1=(0, b1), slope=m1, label=f'$y = {m1:.3f}x {b1:+.3f}$')
#plt.legend()
plt.tight_layout()
plt.legend()
plt.savefig("XY_different_cadences.png", bbox_inches = 'tight', dpi = 300)

# %% [markdown]
# <h1>Introducing spatial convolution, FWHM = 300, 600, 1200 km</h1>

# %% [markdown]
# <h2>FWHM = 600 km</h2>

# %%
Vx_10filtered22 = gaussian_filter(Vx_mean_sim90, 22.5/np.sqrt(2), mode = "wrap")
Vy_10filtered22 = gaussian_filter(Vy_mean_sim90, 22.5/np.sqrt(2), mode = "wrap")

# %%
Rx_conv10 = pearsonr(Vx_10filtered22.flatten(), Vx_10filtered22.flatten())
print(Rx_conv10)
# Out:
# PearsonRResult(statistic=0.9999999999999993, pvalue=0.0)

# %%
Ry_conv10 = pearsonr(Vy_10filtered22.flatten(), Vy_10filtered22.flatten())
print(Ry_conv10)
# Out:
# PearsonRResult(statistic=0.9999999999999999, pvalue=0.0)

# %%
Vx_20filtered22 = gaussian_filter(Vx_mean2_sim90, 22.5/np.sqrt(2), mode = "wrap")
Vy_20filtered22 = gaussian_filter(Vy_mean2_sim90, 22.5/np.sqrt(2), mode = "wrap")

# %%
Rx_conv20 = pearsonr(Vx_10filtered22.flatten(), Vx_20filtered22.flatten())
print(Rx_conv20)
# Out:
# PearsonRResult(statistic=0.8765590567315495, pvalue=0.0)

# %%
Ry_conv20 = pearsonr(Vy_10filtered22.flatten(), Vy_20filtered22.flatten())
print(Ry_conv20)
# Out:
# PearsonRResult(statistic=0.8755597007709307, pvalue=0.0)

# %%
Vx_30filtered22 = gaussian_filter(Vx_mean3_sim90, 22.5/np.sqrt(2), mode = "wrap")
Vy_30filtered22 = gaussian_filter(Vy_mean3_sim90, 22.5/np.sqrt(2), mode = "wrap")

# %%
Rx_conv30 = pearsonr(Vx_10filtered22.flatten(), Vx_30filtered22.flatten())
print(Rx_conv30)
# Out:
# PearsonRResult(statistic=0.7651026512739602, pvalue=0.0)

# %%
Ry_conv30 = pearsonr(Vy_10filtered22.flatten(), Vy_30filtered22.flatten())
print(Ry_conv30)
# Out:
# PearsonRResult(statistic=0.7667860442452421, pvalue=0.0)

# %%
Vx_40filtered22 = gaussian_filter(Vx_mean4_sim90, 22.5/np.sqrt(2), mode = "wrap")
Vy_40filtered22 = gaussian_filter(Vy_mean4_sim90, 22.5/np.sqrt(2), mode = "wrap")

# %%
Rx_conv40 = pearsonr(Vx_10filtered22.flatten(), Vx_40filtered22.flatten())
print(Rx_conv40)
# Out:
# PearsonRResult(statistic=0.6815937084501709, pvalue=0.0)

# %%
Ry_conv40 = pearsonr(Vy_10filtered22.flatten(), Vy_40filtered22.flatten())
print(Ry_conv40)
# Out:
# PearsonRResult(statistic=0.6858960082996459, pvalue=0.0)

# %%
Vx_50filtered22 = gaussian_filter(Vx_mean5_sim90, 22.5/np.sqrt(2), mode = "wrap")
Vy_50filtered22 = gaussian_filter(Vy_mean5_sim90, 22.5/np.sqrt(2), mode = "wrap")

# %%
Rx_conv50 = pearsonr(Vx_10filtered22.flatten(), Vx_50filtered22.flatten())
print(Rx_conv50)
# Out:
# PearsonRResult(statistic=0.6820844365874352, pvalue=0.0)

# %%
Ry_conv50 = pearsonr(Vy_10filtered22.flatten(), Vy_50filtered22.flatten())
print(Ry_conv50)
# Out:
# PearsonRResult(statistic=0.6862368282133775, pvalue=0.0)

# %%
Vx_60filtered22 = gaussian_filter(Vx_mean6_sim90, 22.5/np.sqrt(2), mode = "wrap")
Vy_60filtered22 = gaussian_filter(Vy_mean6_sim90, 22.5/np.sqrt(2), mode = "wrap")

# %%
Rx_conv60 = pearsonr(Vx_10filtered22.flatten(), Vx_60filtered22.flatten())
print(Rx_conv60)
# Out:
# PearsonRResult(statistic=0.6829924445563658, pvalue=0.0)

# %%
Ry_conv60 = pearsonr(Vy_10filtered22.flatten(), Vy_60filtered22.flatten())
print(Ry_conv60)
# Out:
# PearsonRResult(statistic=0.6868091789704228, pvalue=0.0)

# %% [markdown]
# <h2>FWHM = 300 km</h2>

# %%
Vx_10filtered11 = gaussian_filter(Vx_mean_sim90, 11.25/np.sqrt(2), mode = "wrap")
Vy_10filtered11 = gaussian_filter(Vy_mean_sim90, 11.25/np.sqrt(2), mode = "wrap")

# %%
Rx_300conv10 = pearsonr(Vx_10filtered11.flatten(), Vx_10filtered11.flatten())
print(Rx_300conv10)
# Out:
# PearsonRResult(statistic=1.0, pvalue=0.0)

# %%
Ry_300conv10 = pearsonr(Vy_10filtered11.flatten(), Vy_10filtered11.flatten())
print(Ry_300conv10)
# Out:
# PearsonRResult(statistic=0.9999999999999999, pvalue=0.0)

# %%
Vx_20filtered11 = gaussian_filter(Vx_mean2_sim90, 11.25/np.sqrt(2), mode = "wrap")
Vy_20filtered11 = gaussian_filter(Vy_mean2_sim90, 11.25/np.sqrt(2), mode = "wrap")

# %%
Rx_300conv20 = pearsonr(Vx_10filtered11.flatten(), Vx_20filtered11.flatten())
print(Rx_300conv20)
# Out:
# PearsonRResult(statistic=0.8553254319392333, pvalue=0.0)

# %%
Ry_300conv20 = pearsonr(Vy_10filtered11.flatten(), Vy_20filtered11.flatten())
print(Ry_300conv20)
# Out:
# PearsonRResult(statistic=0.8526118749263889, pvalue=0.0)

# %%
Vx_30filtered11 = gaussian_filter(Vx_mean3_sim90, 11.25/np.sqrt(2), mode = "wrap")
Vy_30filtered11 = gaussian_filter(Vy_mean3_sim90, 11.25/np.sqrt(2), mode = "wrap")

# %%
Rx_300conv30 = pearsonr(Vx_10filtered11.flatten(), Vx_30filtered11.flatten())
print(Rx_300conv30)
# Out:
# PearsonRResult(statistic=0.7381041444722274, pvalue=0.0)

# %%
Ry_300conv30 = pearsonr(Vy_10filtered11.flatten(), Vy_30filtered11.flatten())
print(Ry_300conv30)
# Out:
# PearsonRResult(statistic=0.7403490894969398, pvalue=0.0)

# %%
Vx_40filtered11 = gaussian_filter(Vx_mean4_sim90, 11.25/np.sqrt(2), mode = "wrap")
Vy_40filtered11 = gaussian_filter(Vy_mean4_sim90, 11.25/np.sqrt(2), mode = "wrap")

# %%
Rx_300conv40 = pearsonr(Vx_10filtered11.flatten(), Vx_40filtered11.flatten())
print(Rx_300conv40)
# Out:
# PearsonRResult(statistic=0.6532913012066341, pvalue=0.0)

# %%
Ry_300conv40 = pearsonr(Vy_10filtered11.flatten(), Vy_40filtered11.flatten())
print(Ry_300conv40)
# Out:
# PearsonRResult(statistic=0.6594798443379211, pvalue=0.0)

# %%
Vx_50filtered11 = gaussian_filter(Vx_mean5_sim90, 11.25/np.sqrt(2), mode = "wrap")
Vy_50filtered11 = gaussian_filter(Vy_mean5_sim90, 11.25/np.sqrt(2), mode = "wrap")

# %%
Rx_300conv50 = pearsonr(Vx_10filtered11.flatten(), Vx_50filtered11.flatten())
print(Rx_300conv50)
# Out:
# PearsonRResult(statistic=0.6537578115200174, pvalue=0.0)

# %%
Ry_300conv50 = pearsonr(Vy_10filtered11.flatten(), Vy_50filtered11.flatten())
print(Ry_300conv50)
# Out:
# PearsonRResult(statistic=0.6598442636450502, pvalue=0.0)

# %%
Vx_60filtered11 = gaussian_filter(Vx_mean6_sim90, 11.25/np.sqrt(2), mode = "wrap")
Vy_60filtered11 = gaussian_filter(Vy_mean6_sim90, 11.25/np.sqrt(2), mode = "wrap")

# %%
Rx_300conv60 = pearsonr(Vx_10filtered11.flatten(), Vx_60filtered11.flatten())
print(Rx_300conv60)
# Out:
# PearsonRResult(statistic=0.6546991805387115, pvalue=0.0)

# %%
Ry_300conv60 = pearsonr(Vy_10filtered11.flatten(), Vy_60filtered11.flatten())
print(Ry_300conv60)
# Out:
# PearsonRResult(statistic=0.6603895551357704, pvalue=0.0)

# %% [markdown]
# <h2>FWHM = 1200 km</h2>

# %%
Vx_10filtered35 = gaussian_filter(Vx_mean_sim90, 35/np.sqrt(2), mode = "wrap")
Vy_10filtered35 = gaussian_filter(Vy_mean_sim90, 35/np.sqrt(2), mode = "wrap")

# %%
Rx_12conv10 = pearsonr(Vx_10filtered35.flatten(), Vx_10filtered35.flatten())
print(Rx_12conv10)
# Out:
# PearsonRResult(statistic=1.0, pvalue=0.0)

# %%
Ry_12conv10 = pearsonr(Vy_10filtered35.flatten(), Vy_10filtered35.flatten())
print(Ry_12conv10)
# Out:
# PearsonRResult(statistic=0.9999999999999993, pvalue=0.0)

# %%
Vx_20filtered35 = gaussian_filter(Vx_mean2_sim90, 35/np.sqrt(2), mode = "wrap")
Vy_20filtered35 = gaussian_filter(Vy_mean2_sim90, 35/np.sqrt(2), mode = "wrap")

# %%
Rx_12conv20 = pearsonr(Vx_10filtered35.flatten(), Vx_20filtered35.flatten())
print(Rx_12conv20)
# Out:
# PearsonRResult(statistic=0.8955848538249891, pvalue=0.0)

# %%
Ry_12conv20 = pearsonr(Vy_10filtered35.flatten(), Vy_20filtered35.flatten())
print(Ry_12conv20)
# Out:
# PearsonRResult(statistic=0.897832958792212, pvalue=0.0)

# %%
Vx_30filtered35 = gaussian_filter(Vx_mean3_sim90, 35/np.sqrt(2), mode = "wrap")
Vy_30filtered35 = gaussian_filter(Vy_mean3_sim90, 35/np.sqrt(2), mode = "wrap")

# %%
Rx_12conv30 = pearsonr(Vx_10filtered35.flatten(), Vx_30filtered35.flatten())
print(Rx_12conv30)
# Out:
# PearsonRResult(statistic=0.7923741681640806, pvalue=0.0)

# %%
Ry_12conv30 = pearsonr(Vy_10filtered35.flatten(), Vy_30filtered35.flatten())
print(Ry_12conv30)
# Out:
# PearsonRResult(statistic=0.7930707185705608, pvalue=0.0)

# %%
Vx_40filtered35 = gaussian_filter(Vx_mean4_sim90, 35/np.sqrt(2), mode = "wrap")
Vy_40filtered35 = gaussian_filter(Vy_mean4_sim90, 35/np.sqrt(2), mode = "wrap")

# %%
Rx_12conv40 = pearsonr(Vx_10filtered35.flatten(), Vx_40filtered35.flatten())
print(Rx_12conv40)
# Out:
# PearsonRResult(statistic=0.7130871754808294, pvalue=0.0)

# %%
Ry_12conv40 = pearsonr(Vy_10filtered35.flatten(), Vy_40filtered35.flatten())
print(Ry_12conv40)
# Out:
# PearsonRResult(statistic=0.7138558221624045, pvalue=0.0)

# %%
Vx_50filtered35 = gaussian_filter(Vx_mean5_sim90, 35/np.sqrt(2), mode = "wrap")
Vy_50filtered35 = gaussian_filter(Vy_mean5_sim90, 35/np.sqrt(2), mode = "wrap")

# %%
Rx_12conv50 = pearsonr(Vx_10filtered35.flatten(), Vx_50filtered35.flatten())
print(Rx_12conv50)
# Out:
# PearsonRResult(statistic=0.7135787292687275, pvalue=0.0)

# %%
Ry_12conv50 = pearsonr(Vy_10filtered35.flatten(), Vy_50filtered35.flatten())
print(Ry_12conv50)
# Out:
# PearsonRResult(statistic=0.7141214267954128, pvalue=0.0)

# %%
Vx_60filtered35 = gaussian_filter(Vx_mean6_sim90, 35/np.sqrt(2), mode = "wrap")
Vy_60filtered35 = gaussian_filter(Vy_mean6_sim90, 35/np.sqrt(2), mode = "wrap")

# %%
Rx_12conv60 = pearsonr(Vx_10filtered35.flatten(), Vx_60filtered35.flatten())
print(Rx_12conv60)
# Out:
# PearsonRResult(statistic=0.7144134993782697, pvalue=0.0)

# %%
Ry_12conv60 = pearsonr(Vy_10filtered35.flatten(), Vy_60filtered35.flatten())
print(Ry_12conv60)
# Out:
# PearsonRResult(statistic=0.7146911504283364, pvalue=0.0)

# %%
plt.figure(figsize = (12,6))
# FWHM 600 km
niz = [Rx_conv10[0], Rx_conv20[0], Rx_conv30[0], Rx_conv40[0], Rx_conv50[0], Rx_conv60[0]]
niz2 = [10, 20, 30, 40, 50, 60]
niz_y = [Ry_conv10[0], Ry_conv20[0], Ry_conv30[0], Ry_conv40[0], Ry_conv50[0], Ry_conv60[0]]
# FWHM 300 km
niz_300 = [Rx_300conv10[0], Rx_300conv20[0], Rx_300conv30[0], Rx_300conv40[0], Rx_300conv50[0], Rx_300conv60[0]]
niz_300y = [Ry_300conv10[0], Ry_300conv20[0], Ry_300conv30[0], Ry_300conv40[0], Ry_300conv50[0], Ry_300conv60[0]]
# FWHM 1200 km
niz_12 = [Rx_12conv10[0], Rx_12conv20[0], Rx_12conv30[0], Rx_12conv40[0], Rx_12conv50[0], Rx_12conv60[0]]
niz_12y = [Ry_12conv10[0], Ry_12conv20[0], Ry_12conv30[0], Ry_12conv40[0], Ry_12conv50[0], Ry_12conv60[0]]
plt.suptitle("Pearson's coefficient for convolved with Gaussian simulated velocities; 10 s vs {20, 30, 40, 50, 60}s")
plt.scatter(niz2, niz, color = "red", label = "Rx, FWHM = 600 km", marker = ">", s = 20)
plt.scatter(niz2, niz_y, color = "blue", label = "Ry, FWHM = 600 km", marker = "<", s = 10)
plt.scatter(niz2, niz_300, color = "orange", label = "Rx, FWHM = 300 km", marker = "o", s = 20)
plt.scatter(niz2, niz_300y, color = "purple", label = "Ry, FWHM = 300 km", marker = "s", s = 10)
plt.scatter(niz2, niz_12, color = "green", label = "Rx, FWHM = 1200 km", marker = "X", s = 20)
plt.scatter(niz2, niz_12y, color = "yellow", label = "Ry, FWHM = 1200 km", marker = "D", s = 10)
plt.ylabel("Pearson's coefficient of correlation")
plt.xlabel("Cadence [s]")
#m1, b1, *_ = linregress(Vx_FLCT_1200.flatten(), Vx_FLCT_T.flatten())
#plt.axline(xy1=(0, b1), slope=m1, label=f'$y = {m1:.3f}x {b1:+.3f}$')
#plt.legend()
plt.tight_layout()
plt.legend()
plt.savefig("XY_CONV_different_cadences.png", bbox_inches = 'tight', dpi = 300)

# %% [markdown]
# <h2>Tracked velocities</h2>

# %% [markdown]
# <h3>FLCT vs simulation, FWHM = 600 km, 30 s cadence</h3>

# %%
Vx_tracked_600_30 = fits.open("pyFLCT_fwhm_600_dt_30_Inte%3_tracked.fits")[0].data
Vy_tracked_600_30 = fits.open("pyFLCT_fwhm_600_dt_30_Inte%3_tracked.fits")[1].data

# %%
Vx_mean600_30_sim90 = temporal_avg(Vx_tracked_600_30, 0, 90)
#Vx_mean600_30_sim90 = Vx_mean600_30_sim90/1E5

Vy_mean600_30_sim90 = temporal_avg(Vy_tracked_600_30, 0, 90)
#Vy_mean600_30_sim90 = Vy_mean600_30_sim90/1E5

# %%
Rx_600_30_10 = pearsonr(Vx_mean600_30_sim90.flatten(), Vx_30filtered22.flatten())
print(Rx_600_30_10)
# Out:
# PearsonRResult(statistic=0.9406866345868102, pvalue=0.0)

# %%
Ry_600_30_10 = pearsonr(Vy_mean600_30_sim90.flatten(), Vy_30filtered22.flatten())
print(Ry_600_30_10)
# Out:
# PearsonRResult(statistic=0.9449333818424372, pvalue=0.0)

# %% [markdown]
# <h2>FLCT velocities, FWHM = 600 km, cadence 10 vs. 30 seconds</h2>

# %%
Vx_tracked_600_10 = fits.open("pyFLCT_fwhm_600_dt_30_Inte_tracked.fits")[0].data
Vy_tracked_600_10 = fits.open("pyFLCT_fwhm_600_dt_30_Inte_tracked.fits")[1].data

# %%
Vx_mean600_10_sim90 = temporal_avg(Vx_tracked_600_10, 0, 90)
#Vx_mean600_10_sim90 = Vx_mean600_10_sim90/1E5

Vy_mean600_10_sim90 = temporal_avg(Vy_tracked_600_10, 0, 90)
#Vy_mean600_10_sim90 = Vy_mean600_10_sim90/1E5

# %%
Rx_600_FLCT_30vs10 = pearsonr(Vx_mean600_30_sim90.flatten(), Vx_mean600_10_sim90.flatten())
print(Rx_600_FLCT_30vs10)
# Out:
# PearsonRResult(statistic=0.7923472201629871, pvalue=0.0)

# %%
Ry_600_FLCT_30vs10 = pearsonr(Vy_mean600_30_sim90.flatten(), Vy_mean600_10_sim90.flatten())
print(Ry_600_FLCT_30vs10)
# Out:
# PearsonRResult(statistic=0.7982097121308938, pvalue=0.0)

# %% [markdown]
# <h2>FLCT LW</h2>

# %% [markdown]
# <h2>FLCT & LW, FWHM = 600 km, cadence = 30 s</h2>

# %%
Vx_LW_600 = fits.open("pyFLCT_fwhm_600_dt_30_500nmInte_tracked.fits")[0].data
Vy_LW_600 = fits.open("pyFLCT_fwhm_600_dt_30_500nmInte_tracked.fits")[1].data

# %%
Vx_meanLW_600_30_sim90 = temporal_avg(Vx_LW_600, 0, 90)
#Vx_meanLW_600_30_sim90 = Vx_meanLW_600_30_sim90/1E5

Vy_meanLW_600_30_sim90 = temporal_avg(Vy_LW_600, 0, 90)
#Vy_meanLW_600_30_sim90 = Vy_meanLW_600_30_sim90/1E5

# %%
Rx_LW600_FLCT_30 = pearsonr(Vx_30filtered22.flatten(), Vx_meanLW_600_30_sim90.flatten())
print(Rx_LW600_FLCT_30)
# Out:
# PearsonRResult(statistic=0.2214161074847376, pvalue=0.0)

# %%
Ry_LW600_FLCT_30 = pearsonr(Vy_30filtered22.flatten(), Vy_meanLW_600_30_sim90.flatten())
print(Ry_LW600_FLCT_30)
# Out:
# PearsonRResult(statistic=0.42740859832452255, pvalue=0.0)

# %% [markdown]
# <h2>FLCT & LW, FWHM = 600 km, cadence = 10 s</h2>

# %%
Rx_LW600_FLCT_10 = pearsonr(Vx_10filtered22.flatten(), Vx_meanLW_600_30_sim90.flatten())
print(Rx_LW600_FLCT_10)
# Out:
# PearsonRResult(statistic=0.2728241761864597, pvalue=0.0)

# %%
Ry_LW600_FLCT_10 = pearsonr(Vy_10filtered22.flatten(), Vy_meanLW_600_30_sim90.flatten())
print(Ry_LW600_FLCT_10)
# Out:
# PearsonRResult(statistic=0.5090955662062187, pvalue=0.0)

# %% [markdown]
# <h2>FLCT FWHM = 600 km, cadence = 30s vs simulation cadence = 10 s</h2>

# %%
Rx_600_30_sim10 = pearsonr(Vx_mean600_30_sim90.flatten(), Vx_10filtered22.flatten())
print(Rx_600_30_sim10)
# Out:
# PearsonRResult(statistic=0.7150196871873171, pvalue=0.0)

# %%
Ry_600_30_sim10 = pearsonr(Vy_mean600_30_sim90.flatten(), Vy_10filtered22.flatten())
print(Ry_600_30_sim10)
# Out:
# PearsonRResult(statistic=0.7134149169208501, pvalue=0.0)

# %%
fig = plt.figure(figsize=[12, 3.2])       
#plt.suptitle("Simulated velocities averaged to 15 min; 10 s vs 20, 30, 40, 50, 60 s cadence")# atmos[0] tau


plt.subplot(131)                                      # atmos[1] temp
plt.title("Time averaged Simulated Vx, 30 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_30filtered22[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

plt.subplot(132)                                      # atmos[1] temp
plt.title("Time averaged LW Vx, cadence 30 s")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_meanLW_600_30_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()


plt.subplot(133)                                      # atmos[1] temp
plt.title("Time averaged FLCT Vx, cadence 30 s")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_mean600_30_sim90[:, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -1, vmax = 1)
plt.colorbar()

fig.tight_layout()
plt.savefig("LW_nesto", dpi = 100)

# %% [markdown]
# <h4>Correlations</h4>

# %%
r_x1 = pearsonr(Vx_30filtered22.flatten(),Vx_meanLW_600_30_sim90.flatten())
print(r_x1)
# Out:
# PearsonRResult(statistic=0.2214161074847376, pvalue=0.0)

# %%
r_x2 = pearsonr(Vx_30filtered22.flatten(),Vx_mean600_30_sim90.flatten())
print(r_x2)
# Out:
# PearsonRResult(statistic=0.9406866345868102, pvalue=0.0)

# %%
r_x3 = pearsonr(Vx_mean600_30_sim90.flatten(),Vx_meanLW_600_30_sim90.flatten())
print(r_x3)
# Out:
# PearsonRResult(statistic=0.23167928573055846, pvalue=0.0)

# %%
R_prvo = pearsonr(Vx_tracked_600_30[0].flatten(), Vx_LW_600[0].flatten())
print(R_prvo)
# Out:
# PearsonRResult(statistic=0.17644799046380924, pvalue=0.0)

# %%
fig = plt.figure(figsize=[12, 3.2])       
#plt.suptitle("Simulated velocities averaged to 15 min; 10 s vs 20, 30, 40, 50, 60 s cadence")# atmos[0] tau


plt.subplot(131)                                      # atmos[1] temp
plt.title("FLCT Vx, 30 s cadence")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_tracked_600_30[0, :, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -3, vmax = 3)
plt.colorbar()

plt.subplot(132)                                      # atmos[1] temp
plt.title("LW Vx, cadence 30 s")                                # atmos[2]
plt.xlabel("x[Mm]")
plt.ylabel("y[Mm]")
plt.imshow(Vx_LW_600[0, :, :], origin='lower', cmap = "bwr", extent = (0, 24.536, 0, 24.536), vmin = -3, vmax = 3)
plt.colorbar()


plt.subplot(133)                                      # atmos[1] temp
#plt.title("Time averaged FLCT Vx, cadence 30 s")                                # atmos[2]
plt.xlabel("FLCT Vx[0] [km/s]")
plt.ylabel("FLCT LW Vx[0] [km/s]")
plt.scatter(Vx_tracked_600_30[0].flatten(), Vx_LW_600[0].flatten(), alpha=0.05)
plt.xlim([-5,5])
plt.ylim([-5,5])

fig.tight_layout()
plt.savefig("___ff", dpi = 100)
